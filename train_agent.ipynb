# %%
from agent import agent
import numpy as np

# %%
# Para o caso de call, a ação seguinte depende da ação atual. Assim, para manter a propriedade das cadeias de Markov,
# a ação foi adicionada como uma composição do estado do agente.

stateSpace = {
    
    'initial': True,
    'nothing': False, 
    'breeze': False, 
    'stench': False, 
    'danger': False, 
    'flash': False, 
    'goal': False,
    'breezeStench': False, 
    'breezeFlash': False, 
    'stenchFlash': False, 
    'breezeStenchFlash': False,
    
    'initialBoundary': False,
    'nothingBoundary': False, 
    'breezeBoundary': False, 
    'stenchBoundary': False, 
    'flashBoundary': False, 
    'goalBoundary': False,
    'breezeStenchBoundary': False, 
    'breezeFlashBoundary': False, 
    'stenchFlashBoundary': False, 
    'breezeStenchFlashBoundary': False,
    
    'hasGold_initial': False,
    'hasGold_nothing': False, 
    'hasGold_breeze': False, 
    'hasGold_stench': False, 
    'hasGold_danger': False, 
    'hasGold_flash': False, 
    'hasGold_goal': False,  
    'hasGold_breezeStench': False, 
    'hasGold_breezeFlash': False, 
    'hasGold_stenchFlash': False, 
    'hasGold_breezeStenchFlash': False,
    
    'hasGold_initialBoundary': False,
    'hasGold_nothingBoundary': False, 
    'hasGold_breezeBoundary': False, 
    'hasGold_stenchBoundary': False, 
    'hasGold_dangerBoundary': False, 
    'hasGold_flashBoundary': False, 
    'hasGold_goalBoundary': False,  
    'hasGold_breezeStenchBoundary': False, 
    'hasGold_breezeFlashBoundary': False, 
    'hasGold_stenchFlashBoundary': False,
    'hasGold_breezeStenchFlashBoundary': False,
    
    'initial_call_nothing': False, 
    'initial_call_breeze': False, 
    'initial_call_stench': False, 
    'initial_call_danger': False, 
    'initial_call_flash': False, 
    'initial_call_goal': False, 
    'initial_call_breezeStench': False, 
    'initial_call_breezeFlash': False, 
    'initial_call_stenchFlash': False, 
    'initial_call_breezeStenchFlash': False,
    
    'nothing_call_initial': False,
    'nothing_call_nothing': False, 
    'nothing_call_breeze': False, 
    'nothing_call_stench': False, 
    'nothing_call_danger': False, 
    'nothing_call_flash': False, 
    'nothing_call_goal': False,
    'nothing_call_breezeStench': False, 
    'nothing_call_breezeFlash': False, 
    'nothing_call_stenchFlash': False, 
    'nothing_call_breezeStenchFlash': False,
    
    'breeze_call_initial': False,
    'breeze_call_nothing': False, 
    'breeze_call_breeze': False, 
    'breeze_call_stench': False, 
    'breeze_call_danger': False, 
    'breeze_call_flash': False, 
    'breeze_call_goal': False,
    'breeze_call_breezeStench': False, 
    'breeze_call_breezeFlash': False, 
    'breeze_call_stenchFlash': False, 
    'breeze_call_breezeStenchFlash': False,
    
    'stench_call_initial': False,
    'stench_call_nothing': False, 
    'stench_call_breeze': False, 
    'stench_call_stench': False, 
    'stench_call_danger': False, 
    'stench_call_flash': False, 
    'stench_call_goal': False,
    'stench_call_breezeStench': False, 
    'stench_call_breezeFlash': False, 
    'stench_call_stenchFlash': False, 
    'stench_call_breezeStenchFlash': False,
    
    'flash_call_initial': False,
    'flash_call_nothing': False, 
    'flash_call_breeze': False, 
    'flash_call_stench': False, 
    'flash_call_danger': False, 
    'flash_call_goal': False,
    'flash_call_breezeStench': False, 
    'flash_call_breezeFlash': False, 
    'flash_call_stenchFlash': False, 
    'flash_call_breezeStenchFlash': False,
    
    'goal_call_initial': False,
    'goal_call_nothing': False, 
    'goal_call_breeze': False, 
    'goal_call_stench': False, 
    'goal_call_danger': False, 
    'goal_call_flash': False,
    'goal_call_breezeStench': False, 
    'goal_call_breezeFlash': False, 
    'goal_call_stenchFlash': False, 
    'goal_call_breezeStenchFlash': False,

    'breezeStench_call_initial': False,
    'breezeStench_call_nothing': False, 
    'breezeStench_call_breeze': False, 
    'breezeStench_call_stench': False, 
    'breezeStench_call_danger': False, 
    'breezeStench_call_flash': False, 
    'breezeStench_call_goal': False,
    'breezeStench_call_breezeStench': False, 
    'breezeStench_call_breezeFlash': False, 
    'breezeStench_call_stenchFlash': False, 
    'breezeStench_call_breezeStenchFlash': False,

    'breezeFlash_call_initial': False,
    'breezeFlash_call_nothing': False, 
    'breezeFlash_call_breeze': False, 
    'breezeFlash_call_stench': False, 
    'breezeFlash_call_danger': False, 
    'breezeFlash_call_flash': False, 
    'breezeFlash_call_goal': False,
    'breezeFlash_call_breezeStench': False, 
    'breezeFlash_call_breezeFlash': False, 
    'breezeFlash_call_stenchFlash': False, 
    'breezeFlash_call_breezeStenchFlash': False,

    'stenchFlash_call_initial': False,
    'stenchFlash_call_nothing': False, 
    'stenchFlash_call_breeze': False, 
    'stenchFlash_call_stench': False, 
    'stenchFlash_call_danger': False, 
    'stenchFlash_call_flash': False, 
    'stenchFlash_call_goal': False,
    'stenchFlash_call_breezeStench': False, 
    'stenchFlash_call_breezeFlash': False, 
    'stenchFlash_call_stenchFlash': False, 
    'stenchFlash_call_breezeStenchFlash': False,

    'breezeStenchFlash_call_initial': False,
    'breezeStenchFlash_call_nothing': False, 
    'breezeStenchFlash_call_breeze': False, 
    'breezeStenchFlash_call_stench': False, 
    'breezeStenchFlash_call_danger': False, 
    'breezeStenchFlash_call_flash': False, 
    'breezeStenchFlash_call_goal': False,
    'breezeStenchFlash_call_breezeStench': False, 
    'breezeStenchFlash_call_breezeFlash': False, 
    'breezeStenchFlash_call_stenchFlash': False, 
    'breezeStenchFlash_call_breezeStenchFlash': False,
    
    'hasGold_initial_call_nothing': False, 
    'hasGold_initial_call_breeze': False, 
    'hasGold_initial_call_stench': False, 
    'hasGold_initial_call_danger': False, 
    'hasGold_initial_call_flash': False, 
    'hasGold_initial_call_goal': False, 
    'hasGold_initial_call_breezeStench': False, 
    'hasGold_initial_call_breezeFlash': False, 
    'hasGold_initial_call_stenchFlash': False, 
    'hasGold_initial_call_breezeStenchFlash': False,
    
    'hasGold_nothing_call_initial': False,
    'hasGold_nothing_call_nothing': False, 
    'hasGold_nothing_call_breeze': False, 
    'hasGold_nothing_call_stench': False, 
    'hasGold_nothing_call_danger': False, 
    'hasGold_nothing_call_flash': False, 
    'hasGold_nothing_call_goal': False,
    'hasGold_nothing_call_breezeStench': False, 
    'hasGold_nothing_call_breezeFlash': False, 
    'hasGold_nothing_call_stenchFlash': False, 
    'hasGold_nothing_call_breezeStenchFlash': False,
    
    'hasGold_breeze_call_initial': False,
    'hasGold_breeze_call_nothing': False, 
    'hasGold_breeze_call_breeze': False, 
    'hasGold_breeze_call_stench': False, 
    'hasGold_breeze_call_danger': False, 
    'hasGold_breeze_call_flash': False, 
    'hasGold_breeze_call_goal': False,
    'hasGold_breeze_call_breezeStench': False, 
    'hasGold_breeze_call_breezeFlash': False, 
    'hasGold_breeze_call_stenchFlash': False, 
    'hasGold_breeze_call_breezeStenchFlash': False,
    
    'hasGold_stench_call_initial': False,
    'hasGold_stench_call_nothing': False, 
    'hasGold_stench_call_breeze': False, 
    'hasGold_stench_call_stench': False, 
    'hasGold_stench_call_danger': False, 
    'hasGold_stench_call_flash': False, 
    'hasGold_stench_call_goal': False,
    'hasGold_stench_call_breezeStench': False, 
    'hasGold_stench_call_breezeFlash': False, 
    'hasGold_stench_call_stenchFlash': False, 
    'hasGold_stench_call_breezeStenchFlash': False,
    
    'hasGold_flash_call_initial': False,
    'hasGold_flash_call_nothing': False, 
    'hasGold_flash_call_breeze': False, 
    'hasGold_flash_call_stench': False, 
    'hasGold_flash_call_danger': False, 
    'hasGold_flash_call_goal': False,
    'hasGold_flash_call_breezeStench': False, 
    'hasGold_flash_call_breezeFlash': False, 
    'hasGold_flash_call_stenchFlash': False, 
    'hasGold_flash_call_breezeStenchFlash': False,
    
    'hasGold_goal_call_initial': False,
    'hasGold_goal_call_nothing': False, 
    'hasGold_goal_call_breeze': False, 
    'hasGold_goal_call_stench': False, 
    'hasGold_goal_call_danger': False, 
    'hasGold_goal_call_flash': False,
    'hasGold_goal_call_breezeStench': False, 
    'hasGold_goal_call_breezeFlash': False, 
    'hasGold_goal_call_stenchFlash': False, 
    'hasGold_goal_call_breezeStenchFlash': False,

    'hasGold_breezeStench_call_initial': False,
    'hasGold_breezeStench_call_nothing': False, 
    'hasGold_breezeStench_call_breeze': False, 
    'hasGold_breezeStench_call_stench': False, 
    'hasGold_breezeStench_call_danger': False, 
    'hasGold_breezeStench_call_flash': False, 
    'hasGold_breezeStench_call_goal': False,
    'hasGold_breezeStench_call_breezeStench': False, 
    'hasGold_breezeStench_call_breezeFlash': False, 
    'hasGold_breezeStench_call_stenchFlash': False, 
    'hasGold_breezeStench_call_breezeStenchFlash': False,

    'hasGold_breezeFlash_call_initial': False,
    'hasGold_breezeFlash_call_nothing': False, 
    'hasGold_breezeFlash_call_breeze': False, 
    'hasGold_breezeFlash_call_stench': False, 
    'hasGold_breezeFlash_call_danger': False, 
    'hasGold_breezeFlash_call_flash': False, 
    'hasGold_breezeFlash_call_goal': False,
    'hasGold_breezeFlash_call_breezeStench': False, 
    'hasGold_breezeFlash_call_breezeFlash': False, 
    'hasGold_breezeFlash_call_stenchFlash': False, 
    'hasGold_breezeFlash_call_breezeStenchFlash': False,

    'hasGold_stenchFlash_call_initial': False,
    'hasGold_stenchFlash_call_nothing': False, 
    'hasGold_stenchFlash_call_breeze': False, 
    'hasGold_stenchFlash_call_stench': False, 
    'hasGold_stenchFlash_call_danger': False, 
    'hasGold_hasGold_stenchFlash_call_flash': False, 
    'hasGold_stenchFlash_call_goal': False,
    'hasGold_stenchFlash_call_breezeStench': False, 
    'hasGold_stenchFlash_call_breezeFlash': False, 
    'hasGold_stenchFlash_call_stenchFlash': False, 
    'hasGold_stenchFlash_call_breezeStenchFlash': False,

    'hasGold_breezeStenchFlash_call_initial': False,
    'hasGold_breezeStenchFlash_call_nothing': False, 
    'hasGold_breezeStenchFlash_call_breeze': False, 
    'hasGold_breezeStenchFlash_call_stench': False, 
    'hasGold_breezeStenchFlash_call_danger': False, 
    'hasGold_breezeStenchFlash_call_flash': False, 
    'hasGold_breezeStenchFlash_call_goal': False,
    'hasGold_breezeStenchFlash_call_breezeStench': False, 
    'hasGold_breezeStenchFlash_call_breezeFlash': False, 
    'hasGold_breezeStenchFlash_call_stenchFlash': False, 
    'hasGold_breezeStenchFlash_call_breezeStenchFlash': False
}

# Ações possíveis
actionSpace = np.array(["rot_L", "rot_R", "move_F", "grab", "leave", "call_F"])

# %%
# IP do Servidor
server_ip = "192.168.0.204"

# Hiperparâmetros de treinamento do q-learning
epochs = 1000             # Número de epochs
alpha = 0.1               # Taxa de aprendizado
gamma = 0.5               # Peso para recompensa futura
epsilon = 0.1             # Taxa de exploração

# %%
q_agent = agent.Agent(stateSpace, actionSpace, server_ip)
q_agent.fit(epochs, alpha, gamma, epsilon)
